# %%
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.
import scipy.stats as stats
import numpy as np

# Given data
mean = 50
std_dev = 5
n = 30
confidence_level = 0.95

# Calculate the standard error
std_err = std_dev / np.sqrt(n)

# Find the z-score for the 95% confidence level
z_score = stats.norm.ppf(0.975)  # for 95% CI, use 0.975

# Calculate the margin of error
margin_of_error = z_score * std_err

# Calculate the confidence interval
confidence_interval = (mean - margin_of_error, mean + margin_of_error)

confidence_interval
# Out:
# (48.210805856282846, 51.789194143717154)

# %%
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.
from scipy.stats import chisquare

# Observed frequencies
observed = [22, 18, 24, 10, 9, 17]

# Expected frequencies
total = sum(observed)
expected = [total * 0.2, total * 0.2, total * 0.2, total * 0.1, total * 0.1, total * 0.2]

# Perform the chi-square goodness of fit test
chi2_stat, p_val = chisquare(f_obs=observed, f_exp=expected)

chi2_stat, p_val
# Out:
# (1.7500000000000002, 0.8825413740991459)

# %%
# Q3: Chi-Square Test for Contingency Table
# Contingency Table (example):
import pandas as pd
from scipy.stats import chi2_contingency

# Contingency table data
data = [[20, 15, 10],
        [15, 25, 20]]

# Create a DataFrame
table = pd.DataFrame(data, columns=['Outcome 1', 'Outcome 2', 'Outcome 3'], index=['Group A', 'Group B'])

# Perform the chi-square test
chi2, p, dof, ex = chi2_contingency(table)

chi2, p, dof, ex
# Out:
# (4.496527777777778,
#  0.10558236825963216,
#  2,
#  array([[15.        , 17.14285714, 12.85714286],
#         [20.        , 22.85714286, 17.14285714]]))

# %%
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.
import statsmodels.stats.proportion as smp

# Given data
n = 500
p = 60 / 500
confidence_level = 0.95

# Calculate the confidence interval
conf_int = smp.proportion_confint(count=60, nobs=n, alpha=1-confidence_level, method='normal')

conf_int
# Out:
# (0.09151638887130707, 0.1484836111286929)

# %%
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.
# Given data
mean = 75
std_dev = 12
n = 30
confidence_level = 0.90

# Calculate the standard error
std_err = std_dev / np.sqrt(n)

# Find the z-score for the 90% confidence level
z_score = stats.norm.ppf(0.95)  # for 90% CI, use 0.95

# Calculate the margin of error
margin_of_error = z_score * std_err

# Calculate the confidence interval
confidence_interval = (mean - margin_of_error, mean + margin_of_error)

confidence_interval
# Out:
# (71.39630625889797, 78.60369374110203)

# %%
# Q6: Plot Chi-Square Distribution with 10 Degrees of Freedom
import matplotlib.pyplot as plt
import numpy as np

# Degrees of freedom
df = 10

# Generate x values
x = np.linspace(0, 30, 300)

# Chi-square distribution
y = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, y, label='Chi-square distribution (df=10)')

# Shade the area for chi-square statistic of 15
x_fill = np.linspace(15, 30, 100)
y_fill = stats.chi2.pdf(x_fill, df)
plt.fill_between(x_fill, y_fill, color='skyblue', alpha=0.5)

# Labels and title
plt.xlabel('Chi-square value')
plt.ylabel('Probability density')
plt.title('Chi-square distribution with 10 degrees of freedom')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Q7: 99% Confidence Interval for Proportion
# Given data
n = 1000
p = 520 / 1000
confidence_level = 0.99

# Calculate the confidence interval
conf_int = smp.proportion_confint(count=520, nobs=n, alpha=1-confidence_level, method='normal')

conf_int
# Out:
# (0.4793051576779699, 0.5606948423220302)

# %%
# Q8: Chi-Square Goodness of Fit Test for Biased Coin
# Observed frequencies
observed = [45, 55]

# Expected frequencies
expected = [50, 50]

# Perform the chi-square goodness of fit test
chi2_stat, p_val = chisquare(f_obs=observed, f_exp=expected)

chi2_stat, p_val
# Out:
# (1.0, 0.31731050786291115)

# %%
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.
             | Lung Cancer: Yes | Lu
